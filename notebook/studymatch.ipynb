# %%
import warnings
warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
import numpy as np
import pandas as pd
import h5py

import pycbc.conversions, pycbc.distributions, pycbc.waveform, pycbc.filter, pycbc.types, pycbc.psd, pycbc.fft

from tqdm import tqdm
import multiprocessing

from pyseobnr.generate_waveform import GenerateWaveform as eob_td_wf
from matplotlib import pyplot as plt
    
import matplotlib.pyplot
matplotlib.use('Agg')  # or 'TkAgg'

# %%
class GenWaveform(object):
    '''Waveform Generator
    '''
    def __init__(self, buffer_length, sample_rate, f_lower):
        self.f_lower = f_lower
        self.delta_f = 1.0 / buffer_length
        tlen = int(buffer_length * sample_rate) # buffer length x sample_rate
        self.flen = tlen // 2 + 1

        #psd is hard coded to O3 psd
        psd = pycbc.psd.read.from_txt('/work/yifanwang/ecc/templatebank/o3psd.txt', 
            self.flen, self.delta_f, self.f_lower, is_asd_file = False)
        
        self.kmin = int(f_lower * buffer_length)
        self.w = ((1.0 / psd[self.kmin:-1]) ** 0.5).astype(np.float32)
        
        qtilde = pycbc.types.zeros(tlen, np.complex64) # correlation in Fourier domain
        q = pycbc.types.zeros(tlen, np.complex64) # correlation
        self.qtilde_view = qtilde[self.kmin:self.flen - 1]
        self.ifft = pycbc.fft.IFFT(qtilde, q)
        
        # the maximum is around 0
        self.md = q._data[-100:]
        self.md2 = q._data[0:100] 

    def generate(self, **kwds):
        '''Return normalized hp
        '''
        if kwds['approximant'] in pycbc.waveform.fd_approximants():  
            hp, _ = pycbc.waveform.get_fd_waveform(delta_f = self.delta_f, **kwds)
        else:
            dt = 1.0 / self.sample_rate
            hp = pycbc.waveform.get_waveform_filter(
                        pycbc.types.zeros(self.flen, dtype=np.complex64),
                        delta_f=self.delta_f,
                        delta_t=dt,
                        f_lower=self.f_lower,
                        **kwds)
        
        hp.resize(self.flen)
        hp = hp.astype(np.complex64)
        
        hp[self.kmin:-1] *= self.w
        s = pycbc.filter.sigmasq(hp, low_frequency_cutoff=self.f_lower)
        hp /= s**0.5 
        
        hp.params = kwds
        hp.s = s

        return hp

    def match(self, hp, hc):
        hp.view = hp[self.kmin:-1]
        hc.view = hc[self.kmin:-1]
        pycbc.filter.correlate(hp.view, hc.view, self.qtilde_view)
        self.ifft.execute()
        m = max(abs(self.md).max(), abs(self.md2).max())
        return m * 4.0 * self.delta_f

    def overlap(self, hp, hc):
        o = hp.inner(hc)
        return o * 4.0 * self.delta_f
    
def wf_wrapper(p):
    index = p['index']
    try:
        hp = gen.generate(**p)
        return index, hp
    except Exception as e:
        print(e)
        return index, None

def match_wrapper(p):
    '''A wrapper function to compute match
    '''
    h1 =pycbc.types.FrequencySeries(initial_array=p['h1_data'], delta_f=p['h1_delta_f'])
    h2 =pycbc.types.FrequencySeries(initial_array=p['h2_data'], delta_f=p['h2_delta_f'])
    return p['bank_index'], gen.match(h1, h2)

def gen_injections():
    mass_lim = (5, 100)
    spin_lim = (-0.5, 0.5)
    ecc_lim = (0, 0.3)
    ano_lim = (0, 2*np.pi)

    uniform_prior = pycbc.distributions.Uniform(
                            mass1=mass_lim,
                            mass2=mass_lim,
                            spin1z=spin_lim,
                            spin2z=spin_lim,
                            eccentricity=ecc_lim,
                            rel_anomaly=ano_lim)

    def _q_lt_8(params):
        return pycbc.conversions.q_from_mass1_mass2(params["mass1"],params["mass2"]) < 8

    return pycbc.distributions.JointDistribution(["mass1",
                                "mass2",
                                "spin1z",
                                "spin2z",
                                "eccentricity",
                                "rel_anomaly"],
                                uniform_prior,
                                constraints=[_q_lt_8])

def tdwf_wrapper(p):
    p2 = {"approximant": "SEOBNRv5EHM",
          "ModeArray": [(2,2)],
          "f22_start": 20,
          "lmax_nyquist": 1
         }
    p.update(p2)
    index = p['index']
    try:
        wf = eob_td_wf(p)
        hp, _ = wf.generate_td_polarizations()
        return index, abs(float(hp.epoch))
    except Exception as e:
        print(e)
        return index, None

# %%
gen = GenWaveform(buffer_length = 32, sample_rate = 2048, f_lower = 20)

# %% [markdown]
# Read in template bank

# %%
with h5py.File('/work/yifanwang/ecc/src/searchtools/scripts/sucbankprodduration.hdf') as f:
        df_bank = pd.DataFrame(
           {'mass1': f['mass1'][:],
            'mass2': f['mass2'][:],
            'tau0': pycbc.conversions.tau0_from_mass1_mass2(f['mass1'][:],f['mass2'][:],15),
            'eccentricity': f['eccentricity'][:],
            'rel_anomaly': f['rel_anomaly'][:],
            'spin1z': f['spin1z'][:],
            'spin2z': f['spin2z'][:],
            'approximant': f['approximant'][:].astype('str'),
            'f_lower': f['f_lower'][:],
            'template_duration': f['template_duration'][:],}
        )
df_bank['index'] = df_bank.index

# %%
df_bank
# Out:
#             mass1      mass2       tau0  eccentricity  rel_anomaly    spin1z  \
# 0       64.061093  85.262889   0.459226      0.167525     1.997884  0.000620
# 1       68.060491  28.587619   1.115139      0.259024     2.260746  0.176357
# 2       59.947013  61.584384   0.634350      0.031182     1.161729  0.481824
# 3       43.772996  61.903602   0.824914      0.291899     2.723562 -0.367094
# 4       59.499551  76.280133   0.535416      0.234504     1.573280  0.164777
# ...           ...        ...        ...           ...          ...       ...
# 730282   5.025893   5.011645  40.490520      0.179931     3.562414 -0.170420
# 730283   5.020360   5.006370  40.563286      0.295819     1.262575  0.365476
# 730284   5.001911   5.000287  40.729157      0.150412     0.685238  0.282719
# 730285   5.013018   5.012965  40.568248      0.172876     3.767090  0.117018
# 730286   5.001421   5.002662  40.716367      0.245105     3.806413 -0.454715
#
#           spin2z approximant  f_lower  template_duration   index
# 0      -0.081165   SEOBNRv5E     20.0           0.141113       0
# 1      -0.226991   SEOBNRv5E     20.0           0.329590       1
# 2       0.420913   SEOBNRv5E     20.0           0.286133       2
# 3       0.328200   SEOBNRv5E     20.0           0.228516       3
# 4      -0.268736   SEOBNRv5E     20.0           0.150879       4
# ...          ...         ...      ...                ...     ...
# 730282 -0.087774   SEOBNRv5E     20.0          16.978027  730282
# 730283  0.431696   SEOBNRv5E     20.0          14.226562  730283
# 730284  0.463015   SEOBNRv5E     20.0          18.084473  730284
# 730285 -0.025586   SEOBNRv5E     20.0          17.303223  730285
# 730286 -0.492707   SEOBNRv5E     20.0          15.170410  730286
#
# [730287 rows x 11 columns]

# %%
inj = gen_injections()

df_inj = pd.DataFrame(inj.rvs(500))

df_inj['tau0'] = pycbc.conversions.tau0_from_mass1_mass2(df_inj['mass1'],df_inj['mass2'],15)
df_inj['index'] = df_inj.index
df_inj['approximant'] = df_bank['approximant'][0]
df_inj['f_lower'] = df_bank['f_lower'][0]
df_inj['s'] = np.zeros(df_inj.shape[0])


inj_waveform = {}
parlist = ['index', 'approximant', 'f_lower', 'mass1', 'mass2', 'spin1z', 'spin2z', 'eccentricity', 'rel_anomaly']

with multiprocessing.Pool(128) as pool:
    for return_i, return_hp in pool.imap_unordered(
        wf_wrapper,
        ({k: df_inj.loc[idx,k] for k in parlist} for idx in tqdm(df_inj.index))
    ):
        inj_waveform[return_i] = return_hp
        try:
            df_inj.loc[return_i, 's'] = return_hp.s
        except AttributeError:
            df_inj.loc[return_i, 's'] = np.nan

df_inj.to_csv('figure/studymatch/injections.csv', index=False)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.72961313694341) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.80156954964397) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.427744056714863) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# 100%|██████████| 100/100 [00:00<00:00, 3820.99it/s]WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.573044068152168) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 6.100560132306741) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.099097153647126) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.039281063902302) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.187504512023784) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.091358349716694) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 6.259228702156244) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.199730383712643) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.455946538623534) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.292138935162349) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.070238624558289) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.804787005481547) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.016670773376614) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.481586081320943) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.770503916828628) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.531860470639828) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.950945426087347) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.915884081824254) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.594927668972266) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 6.401496686578969) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.1053180598701475) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.43455800538159) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 5.291920559129421) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.674655576155136) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.20001260013363) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.708996868569475) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.164605462470211) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.90486313088031) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.08160693492425748, rel_anomaly = 4.327034490416792, omega_avg = 0.03309849149631679.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.209476126619878) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.2198575440719495) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 6.721258352535412) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 6.617472957725545) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.402405130610723) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.46980377817448) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.74834032850918) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.28631045437265207, rel_anomaly = 3.732184238884526, omega_avg = 0.045399153510136604.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.03702014475288) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.509854119205583) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.799882600460961) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.759844342614918) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.618612884028336) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.681839757478605) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.275444100527586) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.13560316745156) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.499305102534899) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.084687352610512) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.516751679327399) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.506430201621356) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.22553750761560065, rel_anomaly = 5.820478518046266, omega_avg = 0.022950798332543723.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.35423166355645275, rel_anomaly = 4.401450410325346, omega_avg = 0.035160207352152716.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.54305470251802) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.34763530894874) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.13973154294677917, rel_anomaly = 4.477967111731026, omega_avg = 0.03256615405604353.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.630992815962125) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.22331367164755364, rel_anomaly = 4.151202890700116, omega_avg = 0.037679060138052944.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.67863078750085) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.589448107998379) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.16746334761844855, rel_anomaly = 3.5620852497858575, omega_avg = 0.039916727807160955.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.31283103588406064, rel_anomaly = 4.285578013765832, omega_avg = 0.036970724922978024.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.23500409684984863, rel_anomaly = 4.27763510219791, omega_avg = 0.035778915305589895.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.036604250552361856, rel_anomaly = 3.8875802155052934, omega_avg = 0.03273309256173475.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.29779066767463236, rel_anomaly = 4.290095342925318, omega_avg = 0.03666687034600041.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.07518585817590696, rel_anomaly = 3.4645582147928473, omega_avg = 0.03542295014742981.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.23146366489508866, rel_anomaly = 4.899802241240467, omega_avg = 0.028116375788394186.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.18397205199810224, rel_anomaly = 4.027421232731899, omega_avg = 0.03674922200655816.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.33538757440813344, rel_anomaly = 4.297149235552732, omega_avg = 0.03659705987991689.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.15098587834478416, rel_anomaly = 4.509600128104973, omega_avg = 0.03262361842760959.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0

# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.2942520339130341, rel_anomaly = 4.205360175660188, omega_avg = 0.037549807733645586.
# ERROR:pyseobnr.models.SEOBNRv5EHM:Waveform generation failed for q = 1.0882583416279166, chi_1 = -0.29964832859437174, chi_2 = 0.07238143758603022, omega_avg = 0.045399153510136604, omega_inst = 0.03128941767113013, eccentricity = 0.28631045437265207, rel_anomaly = 3.732184238884526. Reference values: eccentricity_ref = 0.28072917318383395, rel_anomaly_ref = 3.8731401200086832, omega_avg_ref = 0.046398223314686314.
# Internal function call failed: Input domain error. The time length of the dynamics is below 200 M. Aborting waveform generation since this could cause non-physical waveforms or problems in subsequent steps of the model. Please, review the physical sense of the input parameters.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.003935740857841789, rel_anomaly = 0.5421855662745206, omega_avg = 0.03144685496598865.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.017771281601883328, rel_anomaly = 5.633054050455609, omega_avg = 0.031092951075065548.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.0017530431843674513, rel_anomaly = 4.683193903423062, omega_avg = 0.031790220542750436.
# ERROR:pyseobnr.eob.dynamics.integrate_ode_ecc:Internal function call failed: Input domain error. The time length of the dynamics is below 200 M. Aborting waveform generation since this could cause non-physical waveforms or problems in subsequent steps of the model. Please, review the physical sense of the input parameters.
# ERROR:pyseobnr.models.SEOBNRv5EHM:Waveform generation failed for q = 1.5538981055637633, chi_1 = -0.3084238196508394, chi_2 = 0.2783947434050388, omega_avg = 0.0446762787049305, omega_inst = 0.028725894577317834, eccentricity = 0.27039839054510395, rel_anomaly = 3.381108438655675.
# Internal function call failed: Input domain error. The time length of the dynamics is below 200 M. Aborting waveform generation since this could cause non-physical waveforms or problems in subsequent steps of the model. Please, review the physical sense of the input parameters.

# %%
def study_match(hpinj, hpinj_tau0, df_bank, tau0_tol=0.5, nproc=128):
    if hpinj == None:
        print("Failed waveform generation in injection")
        return None
    
    neighbor = df_bank[abs(df_bank['tau0'] - hpinj_tau0) < tau0_tol].index
    print("Number of FF jobs =", len(neighbor)) 

    all_fitting_factors = []
    parlist = ['index', 'approximant', 'f_lower', 'mass1', 'mass2', 'spin1z', 'spin2z', 'eccentricity', 'rel_anomaly']
    with multiprocessing.Pool(nproc) as pool:
        for return_i, return_hp in pool.imap_unordered(
            wf_wrapper,
            ({k: df_bank.loc[idx, k] for k in parlist} for idx in tqdm(neighbor))
        ):
            match = gen.match(hpinj, return_hp)
            dict_current = {'bank_row': return_i, 
                            'fittingfactor': match, 
                            'bank_s': return_hp.s,
                            }
            all_fitting_factors += [dict_current]
        
    return all_fitting_factors

# %%
for ii in range(500):
    hpinj = inj_waveform[ii]
    _, hpinj_duration = tdwf_wrapper({k: df_inj.loc[ii,k] for k in parlist})
    hpinj_tau0 = df_inj.loc[ii, 'tau0']
    if hpinj == None:
        print("Failed waveform generation in injections for #", ii)
        continue
    
    allff = study_match(hpinj, hpinj_tau0, df_bank, tau0_tol = 0.5, nproc = 128)
    df_ff = pd.DataFrame(allff)

    df_ff_sorted = df_ff.sort_values('fittingfactor', ascending=False)
    max_index = df_ff_sorted['fittingfactor'].idxmax()
    df_merged = df_ff_sorted.merge(df_bank, left_on='bank_row', right_index=True)
    df_merged.to_csv('figure/studymatch/FF_'+str(ii)+'.csv',index=False)
    
    plt.figure()
    plt.scatter(df_merged['template_duration']-hpinj_duration, 1 - df_merged['fittingfactor'], 
            c=df_merged['tau0'] - hpinj_tau0, s=1)
    plt.colorbar(label='Template Tau0 - Injection Tau0')
    plt.axhline(0.05, color='r', linestyle='--')
    plt.ylabel('1 - Fitting Factor')
    plt.yscale('log')
    #plt.ylim(upp=0.9)
    plt.xlabel('Template Duration - Injection Duration')
    plt.title('Injection duration = '+str(hpinj_duration)+', Injection Tau0 = '+str(hpinj_tau0))
    plt.savefig('figure/studymatch/FF_'+str(ii)+'.png',dpi=100)

    plt.figure()
    plt.scatter(df_merged['template_duration']-hpinj_duration, 1 - df_merged['fittingfactor'], 
            c=df_merged['bank_s'] / hpinj.s, s=1)
    plt.colorbar(label='Template sigma / Injection sigma')
    plt.axhline(0.05, color='r', linestyle='--')
    plt.ylabel('1 - Fitting Factor')
    plt.yscale('log')
    #plt.ylim(upp=0.9)
    plt.xlabel('Template Duration - Injection Duration')
    plt.title('Injection sigma = '+str(hpinj.s))
    plt.savefig('figure/studymatch/FF_'+str(ii)+'_sigma.png',dpi=100)
# Out:
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.29291196609664) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.07572093254507106, rel_anomaly = 4.697215793548013, omega_avg = 0.031722535236425306.
# Number of FF jobs = 12977
#   0%|          | 0/12977 [00:00<?, ?it/s]WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.68532231301176) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.760011267521072) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.155364851491559) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.706404839496701) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.754612042565194) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.42286615438032) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.2728675261650935) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.42850882397256) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.397791654556197) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.712579215133925) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.293040674677066) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.315261288552318) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.372508778059673) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.725678298573701) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.376607923810163) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.327107632435224) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.985469186865632) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.3886548399301) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.222663290613881) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.20949718004114) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.98742495293419) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.694613295092719) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.92202119223396) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.300017278674853) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.812624031010483) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.416760536190411) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.612093794892845) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.28405407872497596, rel_anomaly = 4.276984025667165, omega_avg = 0.036766250368866694.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.626379638603947) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.16645671346321445, rel_anomaly = 4.34214055905661, omega_avg = 0.033791865683347404.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.92507528803991) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.74219854238694) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.2170265109975342, rel_anomaly = 5.066730117014293, omega_avg = 0.02738947405903198.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.44216857849871) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.141651817921115) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.919756317758434) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.543275813321042) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.578590863370204) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.791413953949459) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.566664926901577) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.986108665639133) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.17553909258265932, rel_anomaly = 5.4920935492946, omega_avg = 0.02629292225831856.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.501175393682759) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.921250607782385) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.861265024953248) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.473827132266036) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.10232921997143) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.14868774789647396, rel_anomaly = 3.756361604144283, omega_avg = 0.03763655074298044.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.292747906604147) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.586232711701393) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.18401877629215466, rel_anomaly = 4.53517691518206, omega_avg = 0.03256400674143267.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.838405374188) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.288338567856078) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.038937243482956733, rel_anomaly = 5.087451865585689, omega_avg = 0.030704538288222862.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.3025394103244115, rel_anomaly = 5.017979244073057, omega_avg = 0.025594488191320906.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.749607157703043) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.391962890606614) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.912539116934656) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.27576428837609446, rel_anomaly = 5.139413764295545, omega_avg = 0.025382388722254935.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.14547719323600042, rel_anomaly = 3.6546583517266886, omega_avg = 0.03872283309651928.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.025848070741396) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.07857964334432442, rel_anomaly = 3.483886776511638, omega_avg = 0.03535907642494318.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.849648041208502) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0
is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.12488681541185709, rel_anomaly = 4.137456273984302, omega_avg = 0.03441671771961458.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.27919971752387324, rel_anomaly = 4.182593671794957, omega_avg = 0.03671956128615102.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.25242953023223547, rel_anomaly = 4.182687670809785, omega_avg = 0.03636347611163938.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.963136575800261) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.292035888383458, rel_anomaly = 4.245136759745434, omega_avg = 0.035963532512077255.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.258334841108397) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.683221802790161) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.19070332246167582, rel_anomaly = 4.247540008785397, omega_avg = 0.03482209510473865.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.24891788317662747, rel_anomaly = 4.35262895121353, omega_avg = 0.034029929605691095.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.000974314482328) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.88311224583287) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.3006974273638461, rel_anomaly = 4.267895922969811, omega_avg = 0.03563332667774129.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.980031839914691) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.16803316693735007, rel_anomaly = 4.185771519150068, omega_avg = 0.03493784072696037.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.20929545333926014, rel_anomaly = 4.571768625340506, omega_avg = 0.03170669374997489.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.892050395873953) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.2720750635759188, rel_anomaly = 4.316265696457592, omega_avg = 0.03476855042577838.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.153294358797098) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.1903026683135475, rel_anomaly = 4.1321039793996635, omega_avg = 0.03582205208323684.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.15288022037513) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.907802625564116) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.2953281636698614, rel_anomaly = 4.581644043304457, omega_avg = 0.030846823404607576.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.477407627939283) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.24433902089315146, rel_anomaly = 4.185694082080115, omega_avg = 0.03627914229068555.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.281492971309472, rel_anomaly = 4.18497884584033, omega_avg = 0.03706362637964167.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.705361059526053) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.422793453920622) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.17454819191454665, rel_anomaly = 3.8379719096727314, omega_avg = 0.037752500772559074.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.081185520522325) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.2677918265785329, rel_anomaly = 4.313725083142789, omega_avg = 0.03485237333303392.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.411579264022141) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.2804506839734078, rel_anomaly = 4.351769418167691, omega_avg = 0.03409534871504855.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.2398525009638037, rel_anomaly = 4.378847690026259, omega_avg = 0.033711382846522725.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.052596316689518) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.654326730260145) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.15153456831438206, rel_anomaly = 5.118053605523743, omega_avg = 0.028707114404150524.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.2955938351631076, rel_anomaly = 4.169458494202578, omega_avg = 0.03726318974030217.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.6481817211553) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.25320096285248667, rel_anomaly = 4.648951383893336, omega_avg = 0.030530837793470836.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.8372204361562146) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.961422742216785) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 9.807058772600111) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.24524582278655366, rel_anomaly = 4.304585755077259, omega_avg = 0.03457595973703419.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.3008783712684704, rel_anomaly = 4.565982623969926, omega_avg = 0.031175624345584244.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.24928607124403954, rel_anomaly = 4.411525026606181, omega_avg = 0.03344328265770338.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 8.797614072153191) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.22910026677517445, rel_anomaly = 4.520830899533675, omega_avg = 0.03211260275865535.

# %% [markdown]
# Study #6

# %%
# %matplotlib inline

# %%
df = pd.read_csv('figure/studymatch/injections.csv')

# %%
_, hf = wf_wrapper({k: df.loc[6,k] for k in parlist})
# Out:
# WARNING:pyseobnr.models.SEOBNRv5EHM:The predicted starting separation of the system (r_start = 7.03384880430194) is below the minimum starting separation allowed by the model (r_start_min = 10.0). Integrating backwards in time a set of secular evolution equations to obtain a prediction for the starting separation larger than this minimum. This will change the starting input values of the system.
# WARNING:pyseobnr.models.SEOBNRv5EHM:The new starting input values of the system are: eccentricity = 0.18453947426743172, rel_anomaly = 4.484533426166664, omega_avg = 0.033086774073811956.

# %%
hf

# %%
ht = hf.to_timeseries()

# %%
plt.plot(ht.sample_times, ht)
