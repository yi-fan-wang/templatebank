# %%
import warnings
warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
from pycbc.io import hdf

# %%
trigs = hdf.SingleDetTriggers(
    '/work/yifanwang/ecc/run/t6-cache-fixplotsingles/runs/O3/16/full_data/H1-HDF_TRIGGER_MERGE_FULL_DATA-1248563828-631563.hdf',
    'H1',
    bank_file='/work/yifanwang/ecc/run/t6-cache-fixplotsingles/runs/O3/16/bank/H1L1V1-BANK2HDF-1248563828-631563.hdf',
    filter_rank='newsnr_sgveto_psdvar_scaled_threshold',
    filter_threshold = 6.5
)

# %%
trigs.rel_anomaly
# Out:
# array([2.48814554, 3.22134326, 5.57493823, 3.17892369, 1.67208877,
#        3.38672279, 3.38672279, 4.47204907, 0.05478885, 3.27669854,
#        3.77805967, 4.55480092, 3.15206662, 2.39785395, 0.88764975,
#        1.66949503, 4.4009101 , 2.75090974, 4.51506056, 1.77186716,
#        2.71736929, 5.36992995, 4.02251632, 4.10250431, 2.26371654,
#        3.10604695, 3.10604695, 4.66675095, 2.51071444, 2.51071444,
#        3.89490554, 3.89490554, 2.68785408, 4.86468195, 3.40258137,
#        3.40258137, 4.48524113, 0.31580557, 0.2447855 , 1.27959556,
#        1.27959556, 3.53868396, 0.39492592, 0.69594567, 2.43751388,
#        1.96240975, 3.89261627, 3.89261627, 4.45374498, 1.3960186 ,
#        3.79098298, 3.60185731, 4.17044835, 4.52465927, 4.75412401,
#        4.75412401, 1.36849213, 1.74380245, 1.17195075, 4.38213831,
#        4.38213831, 1.23029875, 1.23029875, 1.23029875, 3.93511917,
#        3.93511917, 4.09952075, 0.57189804, 4.29092887, 3.36907542,
# ...

# %%
trigs.eccentricity
# Out:
# array([0.23136407, 0.25220928, 0.19036545, 0.2013227 , 0.17386546,
#        0.29879072, 0.29879072, 0.29105321, 0.24906059, 0.26797677,
#        0.24410971, 0.20154717, 0.21754244, 0.27840209, 0.26243449,
#        0.14057188, 0.26689905, 0.21380607, 0.2947539 , 0.07914398,
#        0.29992089, 0.26580235, 0.19960364, 0.29894831, 0.29220384,
#        0.17178188, 0.17178188, 0.28396158, 0.28990019, 0.28990019,
#        0.29842747, 0.29842747, 0.17998771, 0.2895636 , 0.2858141 ,
#        0.2858141 , 0.24153361, 0.24924876, 0.29773807, 0.29430442,
#        0.29430442, 0.26754542, 0.28556295, 0.25016743, 0.24580699,
#        0.20720973, 0.20689405, 0.20689405, 0.23927809, 0.15306569,
#        0.29102241, 0.22866136, 0.23271016, 0.21844663, 0.2971344 ,
#        0.2971344 , 0.21692879, 0.26973   , 0.26200379, 0.27599339,
#        0.27599339, 0.299813  , 0.299813  , 0.299813  , 0.29252377,
#        0.29252377, 0.27706174, 0.28084631, 0.24409543, 0.2699731 ,
# ...

# %%
trigs.aaa
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 trigs.aaa                                                                                    │
# │   2                                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# AttributeError: 'SingleDetTriggers' object has no attribute 'aaa'
