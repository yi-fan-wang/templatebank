# %%
import h5py

# %%
f = h5py.File('/work/yifanwang/ecc/bank/rollback/rerun-32buffer/buffer32eccbank.hdf','r')

# %%
params = {k: f[k][:] for k in f}

# %%
len(tuple(params.values())[0])
# Out:
# 730441
